# %%
import pandas as pd

# %%
df=pd.read_csv("Titanic_data.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[['Pclass','Ticket','Fare']]
# Out:
#      Pclass            Ticket     Fare
# 0         3         A/5 21171   7.2500
# 1         1          PC 17599  71.2833
# 2         3  STON/O2. 3101282   7.9250
# 3         1            113803  53.1000
# 4         3            373450   8.0500
# ..      ...               ...      ...
# 886       2            211536  13.0000
# 887       1            112053  30.0000
# 888       3        W./C. 6607  23.4500
# 889       1            111369  30.0000
# 890       3            370376   7.7500
#
# [891 rows x 3 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[df.dtypes[df.dtypes=='int64'].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Cabin','Fare']][4:11:2]
# Out:
#    Cabin     Fare
# 4    NaN   8.0500
# 6    E46  51.8625
# 8    NaN  11.1333
# 10    G6  16.7000

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df['new_col']=df["PassengerId"] + df['Pclass']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        4
# 1      0          PC 17599  71.2833   C85        C        3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        6
# 3      0            113803  53.1000  C123        S        5
# ...

# %%
pd.Categorical(df['Survived'])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
pd.Categorical(df['Name'])
# Out:
# ['Braund, Mr. Owen Harris', 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Heikkinen, Miss. Laina', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'Allen, Mr. William Henry', ..., 'Montvila, Rev. Juozas', 'Graham, Miss. Margaret Edith', 'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell', 'Dooley, Mr. Patrick']
# Length: 891
# Categories (891, object): ['Abbing, Mr. Anthony', 'Abbott, Mr. Rossmore Edward', 'Abbott, Mrs. Stanton (Rosa Hunt)', 'Abelson, Mr. Samuel', ..., 'de Pelsmaeker, Mr. Alfons', 'del Carlo, Mr. Sebastiano', 'van Billiard, Mr. Austin Blyler', 'van Melkebeke, Mr. Philemon']

# %%
df["Name"].unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
len(df[df['Age']>18])-891
# Out:
# -316

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        4
# 1      0          PC 17599  71.2833   C85        C        3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        6
# 3      0            113803  53.1000  C123        S        5
# ...

# %%
len(df[df['Fare']>32])
# Out:
# 211

# %%
len(df[df['Fare']==0])
# Out:
# 15

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  new_col
# ...

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                     Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                    Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        4
# 1      0          PC 17599  71.2833   C85        C        3
# 2      0  STON/O2. 3101282   7.9250   NaN        S        6
# 3      0            113803  53.1000  C123        S        5
# ...

# %%
df[(df['Survived']==1) & (df['Sex']=='female')][0:21:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 9            10         1       2
# 11           12         1       1
# 19           20         1       3
# 25           26         1       3
# 31           32         1       1
# 39           40         1       3
# 44           45         1       3
# 52           53         1       1
# 56           57         1       2
#
#                                                          Name     Sex   Age  \
# 1         Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0
# 3                Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                                   Bonnell, Miss. Elizabeth  female  58.0
# 19                                    Masselmani, Mrs. Fatima  female   NaN
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)  female  38.0
# ...

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.iloc[0:5 ,[0,1,2,3]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry

# %%
df.loc[0:5 ,["PassengerId","Name","Sex"]]
# Out:
#    PassengerId                                                 Name     Sex
# 0            1                              Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2            3                               Heikkinen, Miss. Laina  female
# 3            4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                             Allen, Mr. William Henry    male
# 5            6                                     Moran, Mr. James    male

# %%
df[["PassengerId","Name","Sex"]][0:5]
# Out:
#    PassengerId                                                 Name     Sex
# 0            1                              Braund, Mr. Owen Harris    male
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female
# 2            3                               Heikkinen, Miss. Laina  female
# 3            4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4            5                             Allen, Mr. William Henry    male

# %%
import pandas as pd

# %%
data={'a':[1,2,3,4,5],
      'b':['ashish','mitesh','krish','shudh','rohan'],
      'c':[6,7,8,9,10]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    a       b   c
# 0  1  ashish   6
# 1  2  mitesh   7
# 2  3   krish   8
# 3  4   shudh   9
# 4  5   rohan  10

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#         b   c
# a
# 1  ashish   6
# 2  mitesh   7
# 3   krish   8
# 4   shudh   9
# 5   rohan  10

# %%
df.reset_index()
# Out:
#    a       b   c
# 0  1  ashish   6
# 1  2  mitesh   7
# 2  3   krish   8
# 3  4   shudh   9
# 4  5   rohan  10

# %%
data={'a':[1,2,3,4,5],
      'b':['ashish','mitesh','krish','shudh','rohan'],
      'c':[6,7,8,9,10]}
df1=pd.DataFrame(data,index=['a','b','c','d','e'])

# %%
df2=df1.reindex(['e','b','a','d','c'])

# %%
df2
# Out:
#    a       b   c
# e  5   rohan  10
# b  2  mitesh   7
# a  1  ashish   6
# d  4   shudh   9
# c  3   krish   8

# %%
for i in df1.iterrows():
    print(i)
# Out:
# ('a', a         1
# b    ashish
# c         6
# Name: a, dtype: object)
# ('b', a         2
# b    mitesh
# c         7
# Name: b, dtype: object)
# ('c', a        3
# b    krish
# c        8
# Name: c, dtype: object)
# ('d', a        4
# b    shudh
# c        9
# Name: d, dtype: object)
# ('e', a        5
# b    rohan
# c       10
# Name: e, dtype: object)

# %%
for col,col_item in df1.iteritems():
    print(col,col_item)
# Out:
# a a    1
# b    2
# c    3
# d    4
# e    5
# Name: a, dtype: int64
# b a    ashish
# b    mitesh
# c     krish
# d     shudh
# e     rohan
# Name: b, dtype: object
# c a     6
# b     7
# c     8
# d     9
# e    10
# Name: c, dtype: int64
# C:\Users\ashis\AppData\Local\Temp\ipykernel_18088\2211493698.py:1: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col,col_item in df1.iteritems():

# %%
df1
# Out:
#    a       b   c
# a  1  ashish   6
# b  2  mitesh   7
# c  3   krish   8
# d  4   shudh   9
# e  5   rohan  10

# %%
def test(x):
    return x.sum()
df1.apply(test,axis=0)
# Out:
# a                             15
# b    ashishmiteshkrishshudhrohan
# c                             40
# dtype: object

# %%
df1
# Out:
#    a       b   c
# a  1  ashish   6
# b  2  mitesh   7
# c  3   krish   8
# d  4   shudh   9
# e  5   rohan  10

# %%
df3=df1[['a','c']]

# %%
df3
# Out:
#    a   c
# a  1   6
# b  2   7
# c  3   8
# d  4   9
# e  5  10

# %%
df3.applymap(lambda x:x**2)
# Out:
#     a    c
# a   1   36
# b   4   49
# c   9   64
# d  16   81
# e  25  100

# %%
df1
# Out:
#    a       b   c
# a  1  ashish   6
# b  2  mitesh   7
# c  3   krish   8
# d  4   shudh   9
# e  5   rohan  10

# %%
df=df.reset_index()

# %%
df
# Out:
#    a       b   c
# 0  1  ashish   6
# 1  2  mitesh   7
# 2  3   krish   8
# 3  4   shudh   9
# 4  5   rohan  10

# %%
df.sort_values('b')
# Out:
#    a       b   c
# 0  1  ashish   6
# 2  3   krish   8
# 1  2  mitesh   7
# 4  5   rohan  10
# 3  4   shudh   9

# %%
df.sort_index(ascending=False)
# Out:
#    a       b   c
# 4  5   rohan  10
# 3  4   shudh   9
# 2  3   krish   8
# 1  2  mitesh   7
# 0  1  ashish   6

# %%
pd.set_option("display.max_colwidth",1000)
df4=pd.DataFrame({'Desc':["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of todays professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language."]})

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Desc
# ...

# %%
pd.set_option("display.max_colwidth",1000)
df4=pd.DataFrame({'Desc':["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of todays professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language.","this is my practice work","my name is ashish hirpara"]})

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Desc
# ...

# %%
df4['len']=df4['Desc'].apply(len)

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Desc  \
# ...

# %%
df4['word_count']=df4["Desc"].apply(lambda x:len(x.split()))

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Desc  \
# ...

# %%
df
# Out:
#    a       b   c
# 0  1  ashish   6
# 1  2  mitesh   7
# 2  3   krish   8
# 3  4   shudh   9
# 4  5   rohan  10

# %%
df5=pd.DataFrame({'a':[1,2,4,5,8,7,6,5]})

# %%
df5
# Out:
#    a
# 0  1
# 1  2
# 2  4
# 3  5
# 4  8
# 5  7
# 6  6
# 7  5

# %%
df5['a'].rolling(window=1).mean()
# Out:
# 0    1.0
# 1    2.0
# 2    4.0
# 3    5.0
# 4    8.0
# 5    7.0
# 6    6.0
# 7    5.0
# Name: a, dtype: float64

# %%
df5['a'].rolling(window=3).max()
# Out:
# 0    NaN
# 1    NaN
# 2    4.0
# 3    5.0
# 4    8.0
# 5    8.0
# 6    8.0
# 7    7.0
# Name: a, dtype: float64

# %%
df5['a'].cumsum()
# Out:
# 0     1
# 1     3
# 2     7
# 3    12
# 4    20
# 5    27
# 6    33
# 7    38
# Name: a, dtype: int64

# %%
df5
# Out:
#    a
# 0  1
# 1  2
# 2  4
# 3  5
# 4  8
# 5  7
# 6  6
# 7  5

# %%
date=pd.date_range(start='2023-3-1',end='2023-3-30')

# %%
date
# Out:
# DatetimeIndex(['2023-03-01', '2023-03-02', '2023-03-03', '2023-03-04',
#                '2023-03-05', '2023-03-06', '2023-03-07', '2023-03-08',
#                '2023-03-09', '2023-03-10', '2023-03-11', '2023-03-12',
#                '2023-03-13', '2023-03-14', '2023-03-15', '2023-03-16',
#                '2023-03-17', '2023-03-18', '2023-03-19', '2023-03-20',
#                '2023-03-21', '2023-03-22', '2023-03-23', '2023-03-24',
#                '2023-03-25', '2023-03-26', '2023-03-27', '2023-03-28',
#                '2023-03-29', '2023-03-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date=pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          date
# 0  2023-03-01
# 1  2023-03-02
# 2  2023-03-03
# 3  2023-03-04
# 4  2023-03-05
# 5  2023-03-06
# 6  2023-03-07
# 7  2023-03-08
# 8  2023-03-09
# 9  2023-03-10
# 10 2023-03-11
# 11 2023-03-12
# 12 2023-03-13
# 13 2023-03-14
# 14 2023-03-15
# 15 2023-03-16
# 16 2023-03-17
# 17 2023-03-18
# 18 2023-03-19
# 19 2023-03-20
# 20 2023-03-21
# 21 2023-03-22
# 22 2023-03-23
# 23 2023-03-24
# 24 2023-03-25
# 25 2023-03-26
# 26 2023-03-27
# 27 2023-03-28
# 28 2023-03-29
# 29 2023-03-30

# %%
df7=pd.DataFrame({'date':['2023-3-23','2023-3-22','2023-3-21']})

# %%
df7
# Out:
#         date
# 0  2023-3-23
# 1  2023-3-22
# 2  2023-3-21

# %%
df7.dtypes
# Out:
# date    object
# dtype: object

# %%
df7['update_date']=pd.to_datetime(df7['date'])

# %%
df7
# Out:
#         date update_date
# 0  2023-3-23  2023-03-23
# 1  2023-3-22  2023-03-22
# 2  2023-3-21  2023-03-21

# %%
df7.dtypes
# Out:
# date                   object
# update_date    datetime64[ns]
# dtype: object

# %%
df7['years']=df7['update_date'].dt.year

# %%
df7
# Out:
#         date update_date  years
# 0  2023-3-23  2023-03-23   2023
# 1  2023-3-22  2023-03-22   2023
# 2  2023-3-21  2023-03-21   2023

# %%
df7['months']=df7['update_date'].dt.month

# %%
df7
# Out:
#         date update_date  years  months
# 0  2023-3-23  2023-03-23   2023       3
# 1  2023-3-22  2023-03-22   2023       3
# 2  2023-3-21  2023-03-21   2023       3

# %%
df7['Days']=df7['update_date'].dt.day

# %%
df7
# Out:
#         date update_date  years  months  Days
# 0  2023-3-23  2023-03-23   2023       3    23
# 1  2023-3-22  2023-03-22   2023       3    22
# 2  2023-3-21  2023-03-21   2023       3    21

# %%
pd.Timedelta(days=1,hours=5,minutes=45,seconds=55)
# Out:
# Timedelta('1 days 05:45:55')

# %%
dt=pd.to_datetime('2023-03-21')

# %%
td=pd.Timedelta(days=1)

# %%
dt+td
# Out:
# Timestamp('2023-03-22 00:00:00')

# %%
data=['ashish','krish','hiteh','navin','ashish','ashish']

# %%
cat=pd.Categorical(data)

# %%
cat
# Out:
# ['ashish', 'krish', 'hiteh', 'navin', 'ashish', 'ashish']
# Categories (4, object): ['ashish', 'hiteh', 'krish', 'navin']

# %%
cat.value_counts()
# Out:
# ashish    3
# hiteh     1
# krish     1
# navin     1
# dtype: int64

# %%
d=pd.Series([1,2,3,3,4,5,6,8])

# %%
d.plot()
# Out:
# <Axes: >

# %%
df=pd.DataFrame({'a':[3,4,5,6,7],
                'b':[4,5,6,7,8]})

# %%
df.plot(x='a',y='b')
# Out:
# <Axes: xlabel='a'>

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
d=pd.Series([1,2,3,3,4,5,6,8])

# %%
d.plot.pie()
# Out:
# <Axes: >
